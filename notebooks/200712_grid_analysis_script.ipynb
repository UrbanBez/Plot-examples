# %%
# Import packages

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import ticker
from matplotlib import rc
import seaborn as sns
from scipy.optimize import curve_fit
import scipy.stats

# Set the global font to be Arial, size 10
rc('font',**{'family':'sans-serif','sans-serif':['Arial'],'size':10})

# %%
 # Import data

import tkinter as tk
from tkinter import filedialog

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 320, height = 200, bg = 'lightsteelblue2', relief = 'raised')
canvas1.pack()

def getCSV_data ():
    global df
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv (import_file_path)
    df = df.drop(df.columns[0], axis=1)
    display(df)
    
browseButton_CSV = tk.Button(text="      Import grid data CSV File     ", command=getCSV_data, bg='green', fg='white', font=('arial', 12, 'bold'))
canvas1.create_window(160, 100, window=browseButton_CSV)

root.mainloop()


data_grids = df
# Out:
#         Mean1     Mean2     Mean3     Mean4     Mean5     Mean6     Mean7  \
# 0     754.264   773.432   754.340   823.753   786.505   808.010   826.000
# 1     795.681   813.516   799.309   832.677   810.709   812.639   845.212
# 2     819.132   825.611   798.639   864.548   829.107   841.948   856.423
# 3     795.396   825.947   756.175   853.312   839.447   856.784   868.394
# 4     809.527   847.642   816.701   856.054   844.495   893.660   889.500
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  2917.604  2291.969  2540.072  2246.086  2332.757  2238.897  2106.414
# 331  2846.000  2350.358  2669.969  2171.118  2396.165  2293.691  2115.529
# 332  2767.791  2204.263  2634.423  2162.581  2488.456  2282.041  2106.414
# 333  2827.758  2259.726  2569.412  2100.333  2247.272  2150.938  1997.740
# 334  2913.703  2287.389  2661.031  2052.871  2306.971  2264.907  2075.115
#
#         Mean8     Mean9    Mean10  ...   Mean432   Mean433   Mean434  \
# 0     812.712   790.084   772.281  ...   756.306   788.118   762.154
# 1     843.567   784.368   844.865  ...   775.041   791.688   763.067
# 2     856.615   829.863   850.406  ...   801.286   812.699   792.221
# 3     858.000   833.800   874.917  ...   812.153   778.161   783.471
# 4     897.462   837.884   891.094  ...   823.969   822.505   811.644
# ..        ...       ...       ...  ...       ...       ...       ...
# 330  2418.135  2414.821  1416.000  ...  2089.061  2235.548  1880.644
# 331  2383.750  2466.916  1471.771  ...  2234.592  2288.355  1981.827
# 332  2261.808  2486.895  1500.167  ...  2163.643  2148.677  1927.202
# 333  2183.442  2468.347  1462.552  ...  2103.061  2185.118  1939.808
# 334  2131.490  2524.674  1452.292  ...  2297.551  2380.559  2017.885
#
#       Mean435   Mean436   Mean437   Mean438   Mean439   Mean440   Mean441
# 0     756.802   779.093   759.411   764.624   748.010   700.386   727.897
# 1     840.333   789.598   792.567   810.416   777.990   761.941   753.782
# 2     815.125   798.570   819.900   794.317   818.000   785.604   772.103
# 3     789.594   766.150   784.544   771.703   806.479   738.218   766.839
# 4     827.385   783.495   816.833   771.703   827.781   758.178   776.092
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  1839.990  2871.280  1831.844  1752.277  1607.010  1360.535  1849.828
# 331  1942.115  3165.037  1977.233  1879.356  1658.073  1377.089  2012.770
# 332  1999.010  3185.542  1842.622  1855.752  1648.740  1337.099  1925.253
# 333  1962.906  2673.383  1857.844  1824.257  1673.885  1369.772  1911.920
# 334  2016.167  3282.514  1986.322  2004.129  1750.365  1389.475  2141.908
#
# [335 rows x 441 columns]

# %%
 # Import data

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 320, height = 200, bg = 'oldlace', relief = 'raised')
canvas1.pack()

def getCSV_noise ():
    global df
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv (import_file_path)
    df = df.drop(df.columns[0], axis=1)
    display(df)
        
    
browseButton_CSV = tk.Button(text="      Import noise data CSV File     ", command=getCSV_noise, bg='red', fg='white', font=('arial', 12, 'bold'))
canvas1.create_window(160, 100, window=browseButton_CSV)

root.mainloop()


data_noise = df
# Out:
#       Mean
# 0  510.098

# %%
# Subtract the noise

data_grids_sub = data_grids-data_noise.iloc[0,0]

# Time column

time = [t*0.5 for t in range(0,data_grids_sub.shape[0])]
data_grids_sub['Time'] = time

display(data_grids_sub)
# Out:
#         Mean1     Mean2     Mean3     Mean4     Mean5     Mean6     Mean7  \
# 0     244.166   263.334   244.242   313.655   276.407   297.912   315.902
# 1     285.583   303.418   289.211   322.579   300.611   302.541   335.114
# 2     309.034   315.513   288.541   354.450   319.009   331.850   346.325
# 3     285.298   315.849   246.077   343.214   329.349   346.686   358.296
# 4     299.429   337.544   306.603   345.956   334.397   383.562   379.402
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  2407.506  1781.871  2029.974  1735.988  1822.659  1728.799  1596.316
# 331  2335.902  1840.260  2159.871  1661.020  1886.067  1783.593  1605.431
# 332  2257.693  1694.165  2124.325  1652.483  1978.358  1771.943  1596.316
# 333  2317.660  1749.628  2059.314  1590.235  1737.174  1640.840  1487.642
# 334  2403.605  1777.291  2150.933  1542.773  1796.873  1754.809  1565.017
#
#         Mean8     Mean9   Mean10  ...   Mean433   Mean434   Mean435   Mean436  \
# 0     302.614   279.986  262.183  ...   278.020   252.056   246.704   268.995
# 1     333.469   274.270  334.767  ...   281.590   252.969   330.235   279.500
# 2     346.517   319.765  340.308  ...   302.601   282.123   305.027   288.472
# 3     347.902   323.702  364.819  ...   268.063   273.373   279.496   256.052
# 4     387.364   327.786  380.996  ...   312.407   301.546   317.287   273.397
# ..        ...       ...      ...  ...       ...       ...       ...       ...
# 330  1908.037  1904.723  905.902  ...  1725.450  1370.546  1329.892  2361.182
# 331  1873.652  1956.818  961.673  ...  1778.257  1471.729  1432.017  2654.939
# 332  1751.710  1976.797  990.069  ...  1638.579  1417.104  1488.912  2675.444
# 333  1673.344  1958.249  952.454  ...  1675.020  1429.710  1452.808  2163.285
# 334  1621.392  2014.576  942.194  ...  1870.461  1507.787  1506.069  2772.416
#
#       Mean437   Mean438   Mean439  Mean440   Mean441   Time
# 0     249.313   254.526   237.912  190.288   217.799    0.0
# 1     282.469   300.318   267.892  251.843   243.684    0.5
# 2     309.802   284.219   307.902  275.506   262.005    1.0
# 3     274.446   261.605   296.381  228.120   256.741    1.5
# 4     306.735   261.605   317.683  248.080   265.994    2.0
# ..        ...       ...       ...      ...       ...    ...
# 330  1321.746  1242.179  1096.912  850.437  1339.730  165.0
# 331  1467.135  1369.258  1147.975  866.991  1502.672  165.5
# 332  1332.524  1345.654  1138.642  827.001  1415.155  166.0
# 333  1347.746  1314.159  1163.787  859.674  1401.822  166.5
# 334  1476.224  1494.031  1240.267  879.377  1631.810  167.0
#
# [335 rows x 442 columns]

# %%
#### PLOT ####

from pandas import *

data_grids_sub_means = data_grids_sub.filter(regex='Mean')

#################################

sns.set(style="ticks", palette="colorblind")

fig = plt.figure(figsize=(3*1.618,3), dpi = 300) # golden ratio
ax1 = fig.add_subplot(111)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax1.tick_params('both', length=6, width=1.2, which='major')
ax1.tick_params('both', length=4, width=1.2, which='minor')

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(1.2)    

cm = plt.get_cmap('plasma')
ax1.set_prop_cycle('color',[cm(1.*i/data_grids_sub_means.shape[1]) for i in range(data_grids_sub_means.shape[1])])

# Plot the data.

for i in range(0,data_grids_sub_means.shape[1]):
    ax1.plot(data_grids_sub['Time'], data_grids_sub_means.iloc[:,i], linewidth=1.6, alpha=0.7)

# Define y range.

ax1.set_ylim([100, 4e3])

# Set the axis and tick properties

ax1.autoscale(enable=True, axis='x', tight=True)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
locx = ticker.MultipleLocator(base=30) # this locator puts ticks at regular intervals
ax1.xaxis.set_major_locator(locx)
locy = ticker.MultipleLocator(base=1e3) # this locator puts ticks at regular intervals
ax1.yaxis.set_major_locator(locy)

# Label the axis.

ax1.set_xlabel("time (min)", fontsize=15)
ax1.set_ylabel("fluorescence intensity", fontsize=15)

# Set the font for .svg export

plt.rcParams.update({'mathtext.default':  'regular', "svg.fonttype": 'none' })

sns.despine()

# Save the figure

# plt.savefig('200615_100nM_timecourses.png', format='png', dpi = 300, bbox_inches='tight',edgecolor='none')
# plt.savefig('fig1B_example.svg', format='svg', bbox_inches='tight',edgecolor='none')

# %%
# Filter activated compartments with intensity cutoff

k = 1000

data_grids_sub_means_active = pd.DataFrame()

for i in range(data_grids_sub_means.shape[1]):
    if data_grids_sub_means.iloc[-1,i]>k:
        data_grids_sub_means_active=data_grids_sub_means_active.append(data_grids_sub_means.iloc[:,i])
data_grids_sub_means_active=data_grids_sub_means_active.transpose()       
display(data_grids_sub_means_active)
# Out:
#         Mean1     Mean2     Mean3     Mean4     Mean5     Mean6     Mean7  \
# 0     244.166   263.334   244.242   313.655   276.407   297.912   315.902
# 1     285.583   303.418   289.211   322.579   300.611   302.541   335.114
# 2     309.034   315.513   288.541   354.450   319.009   331.850   346.325
# 3     285.298   315.849   246.077   343.214   329.349   346.686   358.296
# 4     299.429   337.544   306.603   345.956   334.397   383.562   379.402
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  2407.506  1781.871  2029.974  1735.988  1822.659  1728.799  1596.316
# 331  2335.902  1840.260  2159.871  1661.020  1886.067  1783.593  1605.431
# 332  2257.693  1694.165  2124.325  1652.483  1978.358  1771.943  1596.316
# 333  2317.660  1749.628  2059.314  1590.235  1737.174  1640.840  1487.642
# 334  2403.605  1777.291  2150.933  1542.773  1796.873  1754.809  1565.017
#
#         Mean8     Mean9    Mean11  ...   Mean431   Mean432   Mean433  \
# 0     302.614   279.986   224.875  ...   299.072   246.208   278.020
# 1     333.469   274.270   260.578  ...   322.211   264.943   281.590
# 2     346.517   319.765   279.078  ...   337.785   291.188   302.601
# 3     347.902   323.702   284.470  ...   299.349   302.055   268.063
# 4     387.364   327.786   289.578  ...   327.700   313.871   312.407
# ..        ...       ...       ...  ...       ...       ...       ...
# 330  1908.037  1904.723  1486.888  ...  1358.338  1578.963  1725.450
# 331  1873.652  1956.818  1468.767  ...  1567.221  1724.494  1778.257
# 332  1751.710  1976.797  1441.078  ...  1452.030  1653.545  1638.579
# 333  1673.344  1958.249  1435.564  ...  1500.679  1592.963  1675.020
# 334  1621.392  2014.576  1481.240  ...  1651.413  1787.453  1870.461
#
#       Mean434   Mean435   Mean436   Mean437   Mean438   Mean439   Mean441
# 0     252.056   246.704   268.995   249.313   254.526   237.912   217.799
# 1     252.969   330.235   279.500   282.469   300.318   267.892   243.684
# 2     282.123   305.027   288.472   309.802   284.219   307.902   262.005
# 3     273.373   279.496   256.052   274.446   261.605   296.381   256.741
# 4     301.546   317.287   273.397   306.735   261.605   317.683   265.994
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  1370.546  1329.892  2361.182  1321.746  1242.179  1096.912  1339.730
# 331  1471.729  1432.017  2654.939  1467.135  1369.258  1147.975  1502.672
# 332  1417.104  1488.912  2675.444  1332.524  1345.654  1138.642  1415.155
# 333  1429.710  1452.808  2163.285  1347.746  1314.159  1163.787  1401.822
# 334  1507.787  1506.069  2772.416  1476.224  1494.031  1240.267  1631.810
#
# [335 rows x 413 columns]

# %%
# Do a Gompertz fit on active compartments

grid_Gomp_params = pd.DataFrame(columns=data_grids_sub_means_active.columns)
grid_Gomp_errs = pd.DataFrame(columns=data_grids_sub_means_active.columns)

def gomp(x, A, B, Ti, ku):
    return B + (A - B) * np.exp(-np.exp(- np.e*ku * (x - Ti)))

B = 0
A = 6000
Ti = 15
ku = 0.01
guess = np.array([A, B, Ti, ku])

for i in range(data_grids_sub_means_active.shape[1]):
    try:
        popt, pcov = curve_fit(gomp, data_grids_sub['Time'], data_grids_sub_means_active.iloc[:,i], guess, bounds = ((0, -np.inf, 0, 0), (10e4, np.inf, 128.5, 0.2)))
        perr = np.sqrt(np.diag(pcov))
        grid_Gomp_params.iloc[:,i] = popt
        grid_Gomp_errs.iloc[:,i] = perr
    except RuntimeError:
        print("Error - curve_fit failed",data_grids_sub_means_active.columns[i])
        grid_Gomp_params.iloc[:,i] = np.nan
        grid_Gomp_errs.iloc[:,i] = np.nan
    
display(grid_Gomp_params) 
display(grid_Gomp_errs)
# Out:
# Error - curve_fit failed Mean286
#          Mean1        Mean2        Mean3        Mean4        Mean5  \
# 0  2233.393294  1793.903042  1946.815692  2002.002291  1578.083773
# 1     8.023697  -395.596933  -389.425371   459.528271   392.243635
# 2    22.157009     8.715230     6.870934    46.018295    31.678812
# 3     0.015595     0.013062     0.013759     0.019078     0.043278
#
#           Mean6         Mean7        Mean8         Mean9       Mean11  ...  \
# 0  1.836962e+03  1.881623e+03  1841.399043  2.054526e+03  1468.624334  ...
# 1 -7.516741e+02 -6.647427e+02   638.634828 -8.113361e+02   445.713659  ...
# 2  2.739641e-10  9.574820e-09    25.601923  1.254373e-16    42.027968  ...
# 3  1.553872e-02  5.272041e-03     0.074637  9.163650e-03     0.018054  ...
#
#        Mean431      Mean432      Mean433      Mean434      Mean435  \
# 0  1866.201998  1777.623166  1691.147613  1464.465110  1558.276705
# 1   404.190620   339.450309  -130.792780   293.725647   -61.970141
# 2    80.167122    27.458360    14.319243    38.174768    10.542585
# 3     0.005908     0.018037     0.012904     0.021114     0.013047
#
#         Mean436      Mean437      Mean438      Mean439      Mean441
# 0  2.581061e+03  1391.814964  1328.707194  1181.700304  1489.125810
# 1 -1.134403e+03   335.446871   334.260797   354.582430   232.239065
# 2  5.993796e-10    22.068443    66.073562    62.493728    21.404214
# 3  5.575339e-03     0.056519     0.026393     0.013198     0.023664
#
# [4 rows x 413 columns]
#        Mean1       Mean2       Mean3      Mean4      Mean5       Mean6  \
# 0  12.389439   15.171385   14.111446  11.390450   7.447662    7.967867
# 1  91.481954  327.277640  366.382161  17.753352  16.711235  417.120406
# 2   1.938639    7.088377    6.975419   0.699194   0.482660    5.966028
# 3   0.000716    0.001044    0.001059   0.000771   0.002618    0.000863
#
#         Mean7      Mean8       Mean9     Mean11  ...     Mean431    Mean432  \
# 0   92.115838  14.348114   17.735113   8.841301  ...  239.965932   8.972229
# 1  790.453771  36.278077  424.496868  16.107840  ...   95.325242  38.462597
# 2   33.466317   0.711285    9.340181   0.924536  ...    8.497718   1.250302
# 3    0.001048   0.011736    0.000586   0.000868  ...    0.001736   0.000825
#
#       Mean433    Mean434     Mean435      Mean436    Mean437   Mean438  \
# 0   12.458041   7.147290   11.867423   188.760125   5.293330  9.213118
# 1  174.215381  14.672916  222.409323  1794.903604  15.773605  9.301291
# 2    4.806549   0.655707    6.618575    49.448310   0.372845  0.602784
# 3    0.000849   0.000813    0.001040     0.001650   0.003324  0.001402
#
#      Mean439    Mean441
# 0  12.597335   6.723636
# 1  10.329101  36.882911
# 2   1.069951   1.073042
# 3   0.000709   0.001149
#
# [4 rows x 413 columns]

# %%
# Display parameter histograms

#### PLOT ####

sns.set(style="ticks", palette="colorblind")

fig = plt.figure(figsize=(3*1.618,3), dpi = 300) # golden ratio
ax1 = fig.add_subplot(111)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax1.tick_params('both', length=6, width=1.2, which='major')
ax1.tick_params('both', length=4, width=1.2, which='minor')

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(1.2)    

palette = sns.color_palette(n_colors=10)

# Plot the data.

sns.distplot(grid_Gomp_params.iloc[3],fit=scipy.stats.lognorm, kde=False,norm_hist=True)
norm_params = scipy.stats.lognorm.fit(grid_Gomp_params.iloc[3].dropna())
print('Gaussian parameters', norm_params)

# Define y range.

# ax1.set_ylim([200, 8e3])

# Set the axis and tick properties

ax1.autoscale(enable=True, axis='x', tight=True)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

# Label the axis.

ax1.set_xlabel("$\it{k_{max}}$ $(min^{-1})$", fontsize=15)
ax1.set_ylabel("density", fontsize=15)

# Set the font for .svg export

plt.rcParams.update({'mathtext.default':  'regular', "svg.fonttype": 'none' })

sns.despine()

# Save the figure

# plt.savefig('200615_100nM_kmax_hist.png', format='png', dpi = 150, bbox_inches='tight',edgecolor='none')
# plt.savefig('fig1B_example.svg', format='svg', bbox_inches='tight',edgecolor='none')
# Out:
# Gaussian parameters (0.6322018357309744, -0.00414382708714882, 0.019325224391272187)

# %%
# Display parameter histograms

#### PLOT ####

sns.set(style="ticks", palette="colorblind")

fig = plt.figure(figsize=(3*1.618,3), dpi = 300) # golden ratio
ax1 = fig.add_subplot(111)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax1.tick_params('both', length=6, width=1.2, which='major')
ax1.tick_params('both', length=4, width=1.2, which='minor')

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(1.2)    

palette = sns.color_palette(n_colors=10)

# Plot the data.

sns.distplot(grid_Gomp_params.iloc[2],fit=scipy.stats.norm, kde=False,norm_hist=True)
norm_params = scipy.stats.norm.fit(grid_Gomp_params.iloc[2].dropna())
print('Gaussian parameters', norm_params)

# Define y range.

# ax1.set_ylim([200, 8e3])

# Set the axis and tick properties

ax1.autoscale(enable=True, axis='x', tight=True)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

# Label the axis.

ax1.set_xlabel("$\it{T_{i}}$ (min)", fontsize=15)
ax1.set_ylabel("density", fontsize=15)

# Set the font for .svg export

plt.rcParams.update({'mathtext.default':  'regular', "svg.fonttype": 'none' })

sns.despine()

# Save the figure

# plt.savefig('200615_100nM_ti_hist.png', format='png', dpi = 150, bbox_inches='tight',edgecolor='none')
# plt.savefig('fig1B_example.svg', format='svg', bbox_inches='tight',edgecolor='none')
# Out:
# Gaussian parameters (29.41534349821176, 27.823065020216927)

# %%
#### PLOT ####

from pandas import *

data_grids_sub_means = data_grids_sub.filter(regex='Mean')

#################################

sns.set(style="ticks", palette="colorblind")

fig = plt.figure(figsize=(3*1.618,3), dpi = 300) # golden ratio
ax1 = fig.add_subplot(111)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax1.tick_params('both', length=6, width=1.2, which='major')
ax1.tick_params('both', length=4, width=1.2, which='minor')

for axis in ['top','bottom','left','right']:
    ax1.spines[axis].set_linewidth(1.2)    

cm = plt.get_cmap('plasma')
ax1.set_prop_cycle('color',[cm(1.*i/data_grids_sub_means.shape[1]) for i in range(data_grids_sub_means.shape[1])])

# Plot the data.

for i in range(0,data_grids_sub_means_active.shape[1]):
    ax1.plot(data_grids_sub['Time'], data_grids_sub_means_active.iloc[:,i], linewidth=1.0, alpha=0.5)

# Define y range.

ax1.set_ylim([100, 4e3])

# Set the axis and tick properties

ax1.autoscale(enable=True, axis='x', tight=True)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
locx = ticker.MultipleLocator(base=30) # this locator puts ticks at regular intervals
ax1.xaxis.set_major_locator(locx)
locy = ticker.MultipleLocator(base=1e3) # this locator puts ticks at regular intervals
ax1.yaxis.set_major_locator(locy)

# Label the axis.

ax1.set_xlabel("time (min)", fontsize=15)
ax1.set_ylabel("fluorescence intensity", fontsize=15)

# Set the font for .svg export

plt.rcParams.update({'mathtext.default':  'regular', "svg.fonttype": 'none' })

sns.despine()

# Save the figure

# plt.savefig('200615_100nM_timecourses_active.png', format='png', dpi = 300, bbox_inches='tight',edgecolor='none')
# plt.savefig('fig1B_example.svg', format='svg', bbox_inches='tight',edgecolor='none')
